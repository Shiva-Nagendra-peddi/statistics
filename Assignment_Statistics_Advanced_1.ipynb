# %% [markdown]
# **Question 1: What is a random variable in probability theory?**
# Ans:
# In probability theory, a random variable is a function that assigns a numerical value to each outcome of a random experiment.
#
# Think of it like this:
# You perform an experiment with uncertain results (rolling a die, flipping a coin, measuring rainfall tomorrow, etc.).
# The experiment’s sample space lists all possible outcomes.
# The random variable takes each outcome and turns it into a number you can work with mathematically.
#
# **Question 2: What are the types of random variables?**
# Ans:
#   1. Discrete Random Variable
# Definition: Takes a countable number of distinct values (finite or infinite but countable).
#
# Examples:
# Number of heads in 5 coin tosses → possible values:
# 0,1,2,3,4,5
# Number of students absent in a class → possible values:
# 0,1,2,…
# Probability Representation: Probability Mass Function (PMF)
# Graph: Usually a bar chart where each value has a probability height.
#
#   2. Continuous Random Variable
# Definition: Takes values from an uncountable set, typically an interval or the whole real line.
#
# Examples:
# Time taken to run 100 meters (e.g., 10.53 seconds, 10.534 seconds)
# Temperature in a city on a given day
# Probability Representation: Probability Density Function (PDF)
# Graph: Smooth curve where area under curve over a range = probability.
#
# **Question 3: Explain the difference between discrete and continuous distributions.**
# Ans:
# 1. Discrete Probability Distribution
# Definition: Describes the probabilities of a discrete random variable, which can take countable values.
#
# Probability is assigned to each possible value directly via a Probability Mass Function (PMF).
# Key Property:
#
# ∑
# ​i
#  P(X=xi)=1
#
#  Examples:
# Probability distribution of rolling a fair die (values: 1, 2, 3, 4, 5, 6)
# Probability distribution of number of cars passing a checkpoint in 1 minute
#
# 2. Continuous Probability Distribution
# Definition: Describes the probabilities of a continuous random variable, which can take uncountably many values (usually over an interval).
#
# Probability is given by the area under the curve of a Probability Density Function (PDF).
# Key Property:
#              −∞ ∫ ∞
#                   f(x)dx=1
#
# #P(X=a)=0 for any exact value a; probabilities are for ranges of values.
#
# Examples:
# Normal distribution of human heights
# Uniform distribution of time taken to process a transaction.
#
# **Question 4: What is a binomial distribution, and how is it used in probability?**
# Ans:
# Binomial Distribution is a function/Event where
# Number of trials (n) is fixed.
# Probability of success (p) is the same for every trial.
# Trials are independent (one trial’s result does not affect another).
# Random variable X = number of successes in n trials.
#
# Uses in Probability & Statistics
# Quality control: Defective vs. non-defective items in a batch.
# Marketing: Success rate of a campaign (clicked vs. not clicked).
# Sports: Probability of winning a certain number of games.
# Genetics: Probability of inheriting a certain trait.
# ​
#
# **Question 5: What is the standard normal distribution, and why is it important?**
# Ans:
# The standard normal distribution is a special case of the normal (Gaussian) distribution where:
# Mean (μ) = 0
# Standard deviation (σ) = 1
# The random variable is usually denoted as Z, hence called the Z-distribution.
#
# Key Properties
# Symmetrical around the mean (0).
# Bell-shaped curve.
# Total area under the curve = 1.
# The empirical rule applies:
# About 68% of values lie between
# z=−1 and z=1
# About 95% between z=−2 and z=2
# About 99.7% between z=−3 and z=3
#  Why It’s Important
#  Basis for Z-scores:
#  Any normal distribution
# 𝑋 ∼ 𝑁(𝜇,𝜎2)X∼N(μ,σ 2) can be converted to the standard normal distribution via:
#
# 𝑍=𝑋−𝜇𝜎 : Z= X−μ/σ
# ​
#
# This transformation allows comparison of data from different normal distributions on the same scale.
#
# Statistical inference:
# Used in hypothesis testing (Z-tests)
# Helps find probabilities and critical values from Z-tables
# Foundation for many statistical methods
# Real-world modeling:
# Many natural and social phenomena (e.g., heights, IQ scores, measurement errors) approximately follow the normal distribution, so the standard normal form becomes a universal reference.
#
# **Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
# Ans:
# The Central Limit Theorem (CLT) is one of the most important results in statistics because it explains why normal distributions appear so often and allows us to make inferences about populations, even when the population itself is not normally distributed.
#
# Definition
# The CLT states that:
# If you take many random samples of size n from a population with any distribution (with finite mean μ and variance 𝜎2 ), then the sampling distribution of the sample mean will approach a normal distribution as
# n becomes large.
#
# Key Points
# Works regardless of the population’s original shape (skewed, uniform, etc.), as long as variance is finite.
# The mean of the sampling distribution = population mean μ.
# The standard deviation of the sampling distribution (called the standard error).
# For practical purposes,
# 𝑛
# ≥
# 30
# n≥30 is often considered “large enough” for the CLT to hold (though it depends on the population’s shape).
#
# Why It’s Critical
# Foundation of inferential statistics:
#
# Allows us to use the normal distribution to estimate probabilities about sample means.
#
# Enables construction of confidence intervals and execution of hypothesis tests.
#
# Universal applicability:
# Even if the original data is not normal, the distribution of sample means will be approximately normal for large n.
#
# Simplifies analysis:
# Makes complex probability problems manageable by using well-known normal distribution properties.
#
# **Question 7: What is the significance of confidence intervals in statistical analysis?**
# Ans:
# A confidence interval (CI) is a range of values, derived from sample data, that is likely to contain the true population parameter (such as the mean or proportion) with a certain level of confidence.
#
# Instead of giving a single estimate (like the sample mean), we provide a range that accounts for sampling variability.
# Example:
# Sample mean = 50
# 95% confidence interval = (47.5, 52.5)
# This means: We are 95% confident the true population mean lies between 47.5 and 52.5.
#
# Why Confidence Intervals Are Important
# Measure of precision – Narrow intervals indicate more precise estimates.
# Account for uncertainty – Shows how much variability is expected from sampling.
# More informative than point estimates – Provides a range, not just one number.
# Basis for decision-making – If a CI for a mean difference does not include 0, it suggests a statistically significant difference.
# Used in hypothesis testing – CIs can serve as an alternative way to interpret test results.
#
# **Question 8: What is the concept of expected value in a probability distribution?**
# Ans:
# The expected value (also called the mean or expectation) of a probability distribution is the long-run average outcome you would expect if you repeated a random experiment many times.
# It represents the center or balance point of the distribution.
#
# Why It’s Important
# Decision-making under uncertainty: Choose actions with the highest expected payoff.
# Finance: Expected return on investments.
# Gambling & games: Fairness of bets.
# Statistics: Basis for variance, standard deviation, and many other measures.
#
# **Question 9: Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard deviation using NumPy, and draw a histogram to visualize the distribution.**
# Ans:
# Program Below

# %%
#Q9 Prpgram Ans
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate 1000 random numbers from N(50, 5^2)
mean = 50
std_dev = 5
size = 1000

data = np.random.normal(mean, std_dev, size)

# Step 2: Compute sample mean and standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # ddof=1 for sample std deviation

# Step 3: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Standard Deviation: {sample_std:.2f}")

# Step 4: Plot histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Normal Distribution (mean=50, std=5)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.axvline(sample_mean, color='red', linestyle='dashed', linewidth=2, label=f"Mean = {sample_mean:.2f}")
plt.legend()
plt.show()
# Out:
# Sample Mean: 50.10
# Sample Standard Deviation: 4.90

# %% [markdown]
# **Question 10: You are working as a data analyst for a retail company. The company has collected daily sales data for 2 years and wants you to identify the overall sales trend. Daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,235, 260, 245, 250, 225, 270, 265, 255, 250, 260]**
# ● Explain how you would apply the Central Limit Theorem to estimate the average saleswith a 95% confidence interval.
# ● Write the Python code to compute the mean sales and its confidence interval.
# Ans:
# Applying the Central Limit Theorem (CLT)
# We have daily sales data for a sample (here, 20 days are shown, but real case = 2 years).
# We want to estimate the population mean and a 95% confidence interval (CI).
#
# Also Program below

# %%
#Q10 Program

import numpy as np
import scipy.stats as stats

# Given daily sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Sample statistics
mean_sales = np.mean(daily_sales)
std_sales = np.std(daily_sales, ddof=1)  # sample standard deviation
n = len(daily_sales)

# 95% confidence interval using t-distribution (safer for small samples)
confidence_level = 0.95
alpha = 1 - confidence_level
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)  # t-critical value

# Margin of error
margin_of_error = t_critical * (std_sales / np.sqrt(n))

# Confidence interval
ci_lower = mean_sales - margin_of_error
ci_upper = mean_sales + margin_of_error

# Output
print(f"Mean Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Mean Sales: 248.25
# 95% Confidence Interval: (240.17, 256.33)
